# %% [markdown]
# ## Votos Congresionales - SQL

# %% [markdown]
# Este cuaderno replica en SQL los principales procedimientos hechos en Python en el cuaderno `votos_congresionales.ipynb`. La primera parte está implementada directamente en SQL, utilizando el módulo `mysql` de Python que me permite conectarme a una base de datos de MySQL que previamente creé y donde cargué los datos de votaciones utilizados en esta prueba.

# %%
# Importar módulos
import pandas as pd
import mysql.connector
import json

# %% [markdown]
# Conexión con base de datos de MySQL

# %%
# Importar credenciales
with open('../src/config', 'r') as f:
    config = json.load(f)

# Crear conexión
cnx = mysql.connector.connect(**config)

# Crear cursor para ejecutar consultas en base de datos
cursor = cnx.cursor(dictionary=True)

# %% [markdown]
# ### Análisis exploratorio y limpieza de los datos

# %% [markdown]
# Visualizar datos

# %%
query = (
    "SELECT * FROM `house-votes-84` LIMIT 4"
)

cursor.execute(query)
pd.DataFrame(cursor)
# Out:
#         party handicapped_infants water_project budget_resolution  \
# 0  republican                   n             y                 n
# 1  republican                   n             y                 n
# 2    democrat                   ?             y                 y
# 3    democrat                   n             y                 y
#
#   physicial_fee_freeze el_salvador_aid religious_groups_schools  \
# 0                    y               y                        y
# 1                    y               y                        y
# 2                    ?               y                        y
# 3                    n               ?                        y
#
#   anti_satellite_test_ban aid_contras mx_missile immigration synfuels_cutback  \
# 0                       n           n          n           y                ?
# 1                       n           n          n           n                n
# 2                       n           n          n           n                y
# 3                       n           n          n           n                y
#
#   education_spending superfund_right_to_sue crime duty_free_exports  \
# 0                  y                      y     y                 n
# 1                  y                      y     y                 n
# 2                  n                      y     y                 n
# 3                  n                      y     n                 n
#
#   export_admin_act_south_africa
# 0                             y
# 1                             ?
# 2                             n
# 3                             y

# %% [markdown]
# Número de observaciones

# %%
query = (
    "SELECT COUNT(*) observaciones FROM `house-votes-84`"
)

cursor.execute(query)
pd.DataFrame(cursor)
# Out:
#    observaciones
# 0            435

# %% [markdown]
# Estructura de los datos

# %%
query = (
    "DESCRIBE `house-votes-84`"
)

cursor.execute(query)
pd.DataFrame(cursor)
# Out:
#                             Field  Type Null Key Default Extra
# 0                           party  text  YES        None
# 1             handicapped_infants  text  YES        None
# 2                   water_project  text  YES        None
# 3               budget_resolution  text  YES        None
# 4            physicial_fee_freeze  text  YES        None
# 5                 el_salvador_aid  text  YES        None
# 6        religious_groups_schools  text  YES        None
# 7         anti_satellite_test_ban  text  YES        None
# 8                     aid_contras  text  YES        None
# 9                      mx_missile  text  YES        None
# 10                    immigration  text  YES        None
# 11               synfuels_cutback  text  YES        None
# 12             education_spending  text  YES        None
# 13         superfund_right_to_sue  text  YES        None
# 14                          crime  text  YES        None
# 15              duty_free_exports  text  YES        None
# 16  export_admin_act_south_africa  text  YES        None

# %% [markdown]
# Validar que en la documentación se refieren a `?` cuando hablan de missing (resultado debe ser 12)

# %%
query = """
SELECT COUNT(*) observaciones 
FROM `house-votes-84`
WHERE handicapped_infants = '?'
"""

cursor.execute(query)
pd.DataFrame(cursor)
# Out:
#    observaciones
# 0             12

# %% [markdown]
# #### Análisis univariado

# %% [markdown]
# Proporción de votos por partido

# %%
query = """
SELECT republicans, 
       republicans / votings * 100 republicans_perc, 
       democrats, 
       democrats / votings * 100 democrats_perc
FROM (
    SELECT 
        SUM(CASE WHEN party = 'republican' THEN 1 ELSE 0 END) republicans,
        SUM(CASE WHEN party = 'democrat' THEN 1 ELSE 0 END) democrats, 
        COUNT(*) votings
    FROM `house-votes-84`
) party_count
"""

cursor.execute(query)
pd.DataFrame(cursor)
# Out:
#   republicans republicans_perc democrats democrats_perc
# 0         168          38.6207       267        61.3793

# %% [markdown]
# Resultados de votaciones

# %%
query = "SELECT column_name FROM INFORMATION_SCHEMA.COLUMNS WHERE TABLE_NAME = 'house-votes-84'"
cursor.execute(query)
columns = [row[0] for row in pd.DataFrame(cursor).values.tolist()]

# %%
for column in columns:
    query = f"""
    SELECT {column}, COUNT(*) votos
    FROM `house-votes-84`
    GROUP BY {column} 
    """

    cursor.execute(query)
    print(pd.DataFrame(cursor), end='\n\n')
# Out:
#   aid_contras  votos
# 0           n    178
# 1           y    242
# 2           ?     15
#
#   anti_satellite_test_ban  votos
# 0                       n    182
# 1                       y    239
# 2                       ?     14
#
#   budget_resolution  votos
# 0                 n    171
# 1                 y    253
# 2                 ?     11
#
#   crime  votos
# 0     y    248
# 1     n    170
# 2     ?     17
#
#   duty_free_exports  votos
# 0                 n    233
# 1                 y    174
# 2                 ?     28
#
#   education_spending  votos
# 0                  y    171
# 1                  n    233
# 2                  ?     31
#
#   el_salvador_aid  votos
# 0               y    212
# 1               ?     15
# 2               n    208
#
#   export_admin_act_south_africa  votos
# 0                             y    269
# 1                             ?    104
# 2                             n     62
#
#   handicapped_infants  votos
# 0                   n    236
# 1                   ?     12
# 2                   y    187
#
#   immigration  votos
# 0           y    216
# 1           n    212
# 2           ?      7
#
#   mx_missile  votos
# 0          n    206
# 1          y    207
# 2          ?     22
#
#         party  votos
# 0  republican    168
# 1    democrat    267
#
#   physicial_fee_freeze  votos
# 0                    y    177
# 1                    ?     11
# 2                    n    247
#
#   religious_groups_schools  votos
# 0                        y    272
# 1                        n    152
# 2                        ?     11
#
#   superfund_right_to_sue  votos
# 0                      y    209
# 1                      ?     25
# 2                      n    201
#
#   synfuels_cutback  votos
# 0                ?     21
# 1                n    264
# 2                y    150
#
#   water_project  votos
# 0             y    195
# 1             n    192
# 2             ?     48

# %% [markdown]
# #### Análisis bivariado

# %%
for column in columns:
    query = f"""
    SELECT party, {column} voto, COUNT(*) votos
    FROM `house-votes-84`
    GROUP BY party, {column}
    ORDER BY party
    """

    cursor.execute(query)
    print(column, ":", sep="")
    print(pd.DataFrame(cursor), end='\n\n')
# Out:
# aid_contras:
#         party voto  votos
# 0    democrat    ?      4
# 1    democrat    n     45
# 2    democrat    y    218
# 3  republican    ?     11
# 4  republican    n    133
# 5  republican    y     24
#
# anti_satellite_test_ban:
#         party voto  votos
# 0    democrat    ?      8
# 1    democrat    n     59
# 2    democrat    y    200
# 3  republican    ?      6
# 4  republican    n    123
# 5  republican    y     39
#
# budget_resolution:
#         party voto  votos
# 0    democrat    ?      7
# 1    democrat    n     29
# 2    democrat    y    231
# 3  republican    ?      4
# 4  republican    n    142
# 5  republican    y     22
#
# crime:
#         party voto  votos
# 0    democrat    ?     10
# 1    democrat    n    167
# 2    democrat    y     90
# 3  republican    ?      7
# 4  republican    n      3
# 5  republican    y    158
#
# duty_free_exports:
#         party voto  votos
# 0    democrat    ?     16
# 1    democrat    n     91
# 2    democrat    y    160
# 3  republican    ?     12
# 4  republican    n    142
# 5  republican    y     14
#
# education_spending:
#         party voto  votos
# 0    democrat    ?     18
# 1    democrat    n    213
# 2    democrat    y     36
# 3  republican    ?     13
# 4  republican    n     20
# 5  republican    y    135
#
# el_salvador_aid:
#         party voto  votos
# 0    democrat    ?     12
# 1    democrat    n    200
# 2    democrat    y     55
# 3  republican    ?      3
# 4  republican    n      8
# 5  republican    y    157
#
# export_admin_act_south_africa:
#         party voto  votos
# 0    democrat    ?     82
# 1    democrat    n     12
# 2    democrat    y    173
# 3  republican    ?     22
# 4  republican    n     50
# 5  republican    y     96
#
# handicapped_infants:
#         party voto  votos
# 0    democrat    ?      9
# 1    democrat    n    102
# 2    democrat    y    156
# 3  republican    ?      3
# 4  republican    n    134
# 5  republican    y     31
#
# immigration:
#         party voto  votos
# 0    democrat    ?      4
# 1    democrat    n    139
# 2    democrat    y    124
# 3  republican    ?      3
# 4  republican    n     73
# 5  republican    y     92
#
# mx_missile:
#         party voto  votos
# 0    democrat    ?     19
# 1    democrat    n     60
# 2    democrat    y    188
# 3  republican    ?      3
# 4  republican    n    146
# 5  republican    y     19
#
# party:
#         party        voto  votos
# 0    democrat    democrat    267
# 1  republican  republican    168
#
# physicial_fee_freeze:
#         party voto  votos
# 0    democrat    ?      8
# 1    democrat    n    245
# 2    democrat    y     14
# 3  republican    ?      3
# 4  republican    n      2
# 5  republican    y    163
#
# religious_groups_schools:
#         party voto  votos
# 0    democrat    ?      9
# 1    democrat    n    135
# 2    democrat    y    123
# 3  republican    ?      2
# 4  republican    n     17
# 5  republican    y    149
#
# superfund_right_to_sue:
#         party voto  votos
# 0    democrat    ?     15
# 1    democrat    n    179
# 2    democrat    y     73
# 3  republican    ?     10
# 4  republican    n     22
# 5  republican    y    136
#
# synfuels_cutback:
#         party voto  votos
# 0    democrat    ?     12
# 1    democrat    n    126
# 2    democrat    y    129
# 3  republican    ?      9
# 4  republican    n    138
# 5  republican    y     21
#
# water_project:
#         party voto  votos
# 0    democrat    ?     28
# 1    democrat    n    119
# 2    democrat    y    120
# 3  republican    ?     20
# 4  republican    n     73
# 5  republican    y     75

# %% [markdown]
# ### Modelación

# %% [markdown]
# Por restricción de tiempo y la complejidad que implica crear estos modelos en SQL, no intentaré resolver esta sección en SQL. Sin embargo, explicaré cuál sería la estrategia general para abordar este problema.
#
# - Para codificar todos los valores de tipo string a numéricas, crearé una vista nueva con las misma observaciones pero utilizaré la cláusula `CASE` para reemplazar todos los valores.
# - Para dividir los datos en conjuntos de prueba y validación, crearía una vista llamada validación que seleccione el 20% de las filas al azar (utilizando `LIM` equivalente al 20% del conteo de observaciones), utilizando la función `RAND()` e incluyendo un `seed` para garantizar que siempre tenga los mismos valores. Después crearía otra vista llamada entrenamiento que incluya los valores de la tabla `house-votes-84` que no estén contenidos en la vista validación.
# - Para calcular las probabilidades `Pr(X=x|y)` que me permitan pronósticar el partido de cada observación/representante crearía una variable para calcular la probabilidad de cada combinación de `x` y `y` para los valores de la observación y las utilizaría en un statement que multiplique cada una de estas variables para encontrar la probabilidad posterior `Pr(Y|X)`, es decir la probabilidad de que el candidato sea republicano.

# %%
cnx.close()
